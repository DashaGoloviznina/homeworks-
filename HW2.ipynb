# %%
text_bigrams = [] # создание списка биграмм
text = ["варкалось хливкие шорьки пырялись по наве и хрюкотали зелюки как мюмзики в мове о бойся бармаглота сын он так свирлеп и дик а в глyще рымит исполин злопастный брандашмыг"]
for word in text:
    x = word.split()
    for i in range(len(x)-1):
        bigram = x[i] + " " + x[i+1] # создание биграмм
        print(bigram)
        text_bigrams.append(bigram) # добавление созданных биграмм в список


print(text_bigrams)
# Out:
# варкалось хливкие
# хливкие шорьки
# шорьки пырялись
# пырялись по
# по наве
# наве и
# и хрюкотали
# хрюкотали зелюки
# зелюки как
# как мюмзики
# мюмзики в
# в мове
# мове о
# о бойся
# бойся бармаглота
# бармаглота сын
# сын он
# он так
# так свирлеп
# свирлеп и
# и дик
# дик а
# а в
# в глyще
# глyще рымит
# рымит исполин
# исполин злопастный
# злопастный брандашмыг
# ['варкалось хливкие', 'хливкие шорьки', 'шорьки пырялись', 'пырялись по', 'по наве', 'наве и', 'и хрюкотали', 'хрюкотали зелюки', 'зелюки как', 'как мюмзики', 'мюмзики в', 'в мове', 'мове о', 'о бойся', 'бойся бармаглота', 'бармаглота сын', 'сын он', 'он так', 'так свирлеп', 'свирлеп и', 'и дик', 'дик а', 'а в', 'в глyще', 'глyще рымит', 'рымит исполин', 'исполин злопастный', 'злопастный брандашмыг']

# %%
import os

print(os.getcwd()) # текущая директория
for file in os.listdir('.'): 
    print(file) # список файлов и папок 
print(len(file)) # количество файлов
# Out:
# C:\Users\Дарья\Desktop\минор\python-dh-hw
# .git
# .gitignore
# .ipynb_checkpoints
# balogh.txt
# hist
# HW1.ipynb
# HW2.ipynb
# poems
# README.md
# 9

# %%
os.chdir("C:/Users/Дарья/Desktop/минор/python-dh-hw/poems") # переход в папку poems

for root, dirs, files in os.walk('.'): 
    for name in files:
        with open(os.path.join(root, name), 'r', encoding='utf-8') as f: # открытие файлов
            text = f.read() # чтение файлов
            with open('poems.txt', 'a', encoding='utf-8') as a: # создание файла poems
                a.write(text) # запись стихотворений в файл poems

# %%
text2 = """Несчастная кошка порезала лапу- 
Сидит, и ни шагу не может ступить.
Скорей, чтобы вылечить кошкину лапу
Воздушные шарики надо купить!

И сразу столпился народ на дороге-
Шумит, и кричит, и на кошку глядит.
А кошка отчасти идет по дороге,
Отчасти по воздуху плавно летит!"""

print(len(text2)) # количество символов в тексте
# Out:
# 270

# %%
words = [word.strip("!?.,-") for word in text2.split()] # создание списка слов
print(words)
# Out:
# ['Несчастная', 'кошка', 'порезала', 'лапу', 'Сидит', 'и', 'ни', 'шагу', 'не', 'может', 'ступить', 'Скорей', 'чтобы', 'вылечить', 'кошкину', 'лапу', 'Воздушные', 'шарики', 'надо', 'купить', 'И', 'сразу', 'столпился', 'народ', 'на', 'дороге', 'Шумит', 'и', 'кричит', 'и', 'на', 'кошку', 'глядит', 'А', 'кошка', 'отчасти', 'идет', 'по', 'дороге', 'Отчасти', 'по', 'воздуху', 'плавно', 'летит']

# %%
text3 = ' '.join(words) # соединение списка в текст
print(text3)
# Out:
# Несчастная кошка порезала лапу Сидит и ни шагу не может ступить Скорей чтобы вылечить кошкину лапу Воздушные шарики надо купить И сразу столпился народ на дороге Шумит и кричит и на кошку глядит А кошка отчасти идет по дороге Отчасти по воздуху плавно летит

# %%
words2 = [w if not w.istitle() else w.lower() for w in text3.split()] # создание списка со словами начинающихся с маленьки букв
print(words2)
# Out:
# ['несчастная', 'кошка', 'порезала', 'лапу', 'сидит', 'и', 'ни', 'шагу', 'не', 'может', 'ступить', 'скорей', 'чтобы', 'вылечить', 'кошкину', 'лапу', 'воздушные', 'шарики', 'надо', 'купить', 'и', 'сразу', 'столпился', 'народ', 'на', 'дороге', 'шумит', 'и', 'кричит', 'и', 'на', 'кошку', 'глядит', 'а', 'кошка', 'отчасти', 'идет', 'по', 'дороге', 'отчасти', 'по', 'воздуху', 'плавно', 'летит']

# %%
print(len(words2)) # количество слов
# Out:
# 44

# %%
print(len(set(words2))) # список уникальных слов
# Out:
# 35

# %%
print(words2[-10:]) # последние 10 слов
# Out:
# ['кошка', 'отчасти', 'идет', 'по', 'дороге', 'отчасти', 'по', 'воздуху', 'плавно', 'летит']

# %%
text4 = '\n'.join(words) # строка через знак переноса
print(text4)
# Out:
# Несчастная
# кошка
# порезала
# лапу
# Сидит
# и
# ни
# шагу
# не
# может
# ступить
# Скорей
# чтобы
# вылечить
# кошкину
# лапу
# Воздушные
# шарики
# надо
# купить
# И
# сразу
# столпился
# народ
# на
# дороге
# Шумит
# и
# кричит
# и
# на
# кошку
# глядит
# А
# кошка
# отчасти
# идет
# по
# дороге
# Отчасти
# по
# воздуху
# плавно
# летит

# %%
print(text4[19:31]) # c 20 по 30 символ строки
# Out:
# резала
# лапу

# %%
# используется текст, полученный в пунке 9 из 3 задания

text4 = ['\n'.join(words)]

text_bigrams = [] # создание списка биграмм
 

for b in text4:
    x = b.split()
    for i in range(len(x)-1):
        bigram = (x[i] + " " + x[i+1]).split() # создание биграмм
        bigram = tuple(bigram) # создание кортежей
        print(bigram)
        
        text_bigrams.append(bigram) # добавление кортежей в список биграмм
        print(text_bigrams.count(bigram)) # частотность биграмм в списке

print(text_bigrams) # список биграмм в виде кортежей
# Out:
# ('Несчастная', 'кошка')
# 1
# ('кошка', 'порезала')
# 1
# ('порезала', 'лапу')
# 1
# ('лапу', 'Сидит')
# 1
# ('Сидит', 'и')
# 1
# ('и', 'ни')
# 1
# ('ни', 'шагу')
# 1
# ('шагу', 'не')
# 1
# ('не', 'может')
# 1
# ('может', 'ступить')
# 1
# ('ступить', 'Скорей')
# 1
# ('Скорей', 'чтобы')
# 1
# ('чтобы', 'вылечить')
# 1
# ('вылечить', 'кошкину')
# 1
# ('кошкину', 'лапу')
# 1
# ('лапу', 'Воздушные')
# 1
# ('Воздушные', 'шарики')
# 1
# ('шарики', 'надо')
# 1
# ('надо', 'купить')
# 1
# ('купить', 'И')
# 1
# ('И', 'сразу')
# 1
# ('сразу', 'столпился')
# 1
# ('столпился', 'народ')
# 1
# ('народ', 'на')
# 1
# ('на', 'дороге')
# 1
# ('дороге', 'Шумит')
# 1
# ('Шумит', 'и')
# 1
# ('и', 'кричит')
# 1
# ('кричит', 'и')
# 1
# ('и', 'на')
# 1
# ('на', 'кошку')
# 1
# ('кошку', 'глядит')
# 1
# ('глядит', 'А')
# 1
# ('А', 'кошка')
# 1
# ('кошка', 'отчасти')
# 1
# ('отчасти', 'идет')
# 1
# ('идет', 'по')
# 1
# ('по', 'дороге')
# 1
# ('дороге', 'Отчасти')
# 1
# ('Отчасти', 'по')
# 1
# ('по', 'воздуху')
# ...
